# %% [markdown]
# # Hovhannes Sukiasyan
# ## Programming Assignment 3
# ## AES implementation

# %%
# AES S-box and Inverse S-box
S_BOX = [
        
]

INV_S_BOX = [
        
]

# Rcon for Key Expansion
RCON = [
    [0x01, 0x00, 0x00, 0x00],
    [0x02, 0x00, 0x00, 0x00],
    [0x04, 0x00, 0x00, 0x00],
    [0x08, 0x00, 0x00, 0x00],
    [0x10, 0x00, 0x00, 0x00],
    [0x20, 0x00, 0x00, 0x00],
    [0x40, 0x00, 0x00, 0x00],
    [0x80, 0x00, 0x00, 0x00],
    [0x1B, 0x00, 0x00, 0x00],
    [0x36, 0x00, 0x00, 0x00]
]

def galois_multiply(a, b):
    p = 0
    for i in range(8):
        if b & 1:
            p ^= a
        hi_bit_set = a & 0x80
        a = (a << 1) & 0xFF
        if hi_bit_set:
            a ^= 0x1B
        b >>= 1
    return p

def sub_bytes(state, sbox):
    for i in range(4):
        for j in range(4):
            state[i][j] = sbox[state[i][j]]
    return state

def shift_rows(state):
    state[1][0], state[1][1], state[1][2], state[1][3] = state[1][1], state[1][2], state[1][3], state[1][0]
    state[2][0], state[2][1], state[2][2], state[2][3] = state[2][2], state[2][3], state[2][0], state[2][1]
    state[3][0], state[3][1], state[3][2], state[3][3] = state[3][3], state[3][0], state[3][1], state[3][2]
    return state

def inv_shift_rows(state):
    state[1][0], state[1][1], state[1][2], state[1][3] = state[1][3], state[1][0], state[1][1], state[1][2]
    state[2][0], state[2][1], state[2][2], state[2][3] = state[2][2], state[2][3], state[2][0], state[2][1]
    state[3][0], state[3][1], state[3][2], state[3][3] = state[3][1], state[3][2], state[3][3], state[3][0]
    return state

def mix_columns(state):
    for i in range(4):
        a = state[0][i]
        b = state[1][i]
        c = state[2][i]
        d = state[3][i]
        
        state[0][i] = galois_multiply(a, 2) ^ galois_multiply(b, 3) ^ c ^ d
        state[1][i] = a ^ galois_multiply(b, 2) ^ galois_multiply(c, 3) ^ d
        state[2][i] = a ^ b ^ galois_multiply(c, 2) ^ galois_multiply(d, 3)
        state[3][i] = galois_multiply(a, 3) ^ b ^ c ^ galois_multiply(d, 2)
    return state

def inv_mix_columns(state):
    for i in range(4):
        a = state[0][i]
        b = state[1][i]
        c = state[2][i]
        d = state[3][i]
        
        state[0][i] = galois_multiply(a, 14) ^ galois_multiply(b, 11) ^ galois_multiply(c, 13) ^ galois_multiply(d, 9)
        state[1][i] = galois_multiply(a, 9) ^ galois_multiply(b, 14) ^ galois_multiply(c, 11) ^ galois_multiply(d, 13)
        state[2][i] = galois_multiply(a, 13) ^ galois_multiply(b, 9) ^ galois_multiply(c, 14) ^ galois_multiply(d, 11)
        state[3][i] = galois_multiply(a, 11) ^ galois_multiply(b, 13) ^ galois_multiply(c, 9) ^ galois_multiply(d, 14)
    return state

def add_round_key(state, round_key):
    for i in range(4):
        for j in range(4):
            state[i][j] ^= round_key[i][j]
    return state

def sub_word(word):
    return [S_BOX[b] for b in word]

def rot_word(word):
    return word[1:] + word[:1]

def generate_key_schedule(key):
    key_schedule = []
    for i in range(4):
        key_schedule.append([key[4 * i], key[4 * i + 1], key[4 * i + 2], key[4 * i + 3]])

    for i in range(4, 4 * 11):
        temp = key_schedule[i - 1]

        if i % 4 == 0:
            temp = sub_word(rot_word(temp))
            temp = [temp[j] ^ RCON[i // 4 - 1][j] for j in range(4)]
        
        word = [key_schedule[i - 4][j] ^ temp[j] for j in range(4)]
        key_schedule.append(word)

    return [key_schedule[4 * i:4 * (i + 1)] for i in range(11)]

def aes_encrypt(plaintext, key_schedule):
    state = [list(plaintext[i:i+4]) for i in range(0, 16, 4)]
    state = add_round_key(state, key_schedule[0])

    for round in range(1, 10):
        state = sub_bytes(state, S_BOX)
        state = shift_rows(state)
        state = mix_columns(state)
        state = add_round_key(state, key_schedule[round])

    state = sub_bytes(state, S_BOX)
    state = shift_rows(state)
    state = add_round_key(state, key_schedule[10])

    return [state[i][j] for i in range(4) for j in range(4)]

def aes_decrypt(ciphertext, key_schedule):
    state = [list(ciphertext[i:i+4]) for i in range(0, 16, 4)]
    state = add_round_key(state, key_schedule[10])

    for round in range(9, 0, -1):
        state = inv_shift_rows(state)
        state = sub_bytes(state, INV_S_BOX)
        state = add_round_key(state, key_schedule[round])
        state = inv_mix_columns(state)

    state = inv_shift_rows(state)
    state = sub_bytes(state, INV_S_BOX)
    state = add_round_key(state, key_schedule[0])

    return [state[i][j] for i in range(4) for j in range(4)]

# Example usage
key = [0x2b, 0x7e, 0x15, 0x16, 0x28, 0xae, 0xd2, 0xa6, 0xab, 0xf7, 0x87, 0x09, 0xcf, 0x4f, 0x3c, 0x76]
plaintext = [0x32, 0x43, 0xf6, 0xa8, 0x88, 0x5a, 0x30, 0x8d, 0x31, 0x31, 0x98, 0xa2, 0xe0, 0x37, 0x07, 0x34]
key_schedule = generate_key_schedule(key)

ciphertext = aes_encrypt(plaintext, key_schedule)
decrypted = aes_decrypt(ciphertext, key_schedule)

print("Plaintext:", plaintext)
print("Ciphertext:", ciphertext)
print("Decrypted:", decrypted)
# Out:
# Plaintext: [50, 67, 246, 168, 136, 90, 48, 141, 49, 49, 152, 162, 224, 55, 7, 52]
# Ciphertext: [134, 145, 64, 130, 148, 250, 224, 65, 120, 53, 163, 119, 190, 93, 81, 247]
# Decrypted: [50, 67, 246, 168, 136, 90, 48, 141, 49, 49, 152, 162, 224, 55, 7, 52]
